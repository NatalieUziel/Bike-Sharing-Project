# %%
#Download all libraries 
import pandas as pd
import numpy as np

# %%
# Read in the CSV file
new = pd.read_csv('/Users/nataliemac/Desktop/VCS/Python/05_Capital_Bike_Share/merged_data.csv', sep=';', low_memory=False)



new
# Out:
#         Duration,Start date,End date,Start station number,Start station,End station number,End station,Bike number,Member type,ride_id,rideable_type,started_at,ended_at,start_station_name,start_station_id,end_station_name,end_station_id,start_lat,start_lng,end_lat,end_lng,member_casual
# 0        506.0,2020-01-01 00:00:59,2020-01-01 00:09:26,...
# 1        1050.0,2020-01-01 00:01:16,2020-01-01 00:18:47...
# 2        1687.0,2020-01-01 00:02:42,2020-01-01 00:30:50...
# 3        182.0,2020-01-01 00:02:44,2020-01-01 00:05:47,...
# 4        1002.0,2020-01-01 00:06:12,2020-01-01 00:22:54...
# ...                                                    ...
# 2216909  ,,,,,,,,,A10ED3D50E5AB612,docked_bike,2020-12-...
# 2216910  ,,,,,,,,,F146CC9669ABF5EC,docked_bike,2020-12-...
# 2216911  ,,,,,,,,,614005BC98FE93F7,docked_bike,2020-12-...
# 2216912  ,,,,,,,,,86783BF38F4567FA,docked_bike,2020-12-...
# 2216913  ,,,,,,,,,A7F61D67643CB526,classic_bike,2020-12...
#
# [2216914 rows x 1 columns]

# %%
# Read in the CSV file
new = pd.read_csv('/Users/nataliemac/Desktop/VCS/Python/05_Capital_Bike_Share/merged_data.csv',low_memory=False)
new
# Out:
#          Duration           Start date             End date  \
# 0           506.0  2020-01-01 00:00:59  2020-01-01 00:09:26
# 1          1050.0  2020-01-01 00:01:16  2020-01-01 00:18:47
# 2          1687.0  2020-01-01 00:02:42  2020-01-01 00:30:50
# 3           182.0  2020-01-01 00:02:44  2020-01-01 00:05:47
# 4          1002.0  2020-01-01 00:06:12  2020-01-01 00:22:54
# ...           ...                  ...                  ...
# 2216909       NaN                  NaN                  NaN
# 2216910       NaN                  NaN                  NaN
# 2216911       NaN                  NaN                  NaN
# 2216912       NaN                  NaN                  NaN
# 2216913       NaN                  NaN                  NaN
#
#          Start station number  \
# 0                     31623.0
# 1                     31613.0
# 2                     31218.0
# 3                     31627.0
# 4                     31247.0
# ...                       ...
# ...

# %%
new = pd.read_csv('/Users/nataliemac/Desktop/VCS/Python/05_Capital_Bike_Share/merged_data.csv', 
                  dtype={'ride_id': 'int', 'ended_at': 'float', 'start_station_game': 'str'})

# %%
print(new.columns)
# Out:
# Index(['Duration', 'Start date', 'End date', 'Start station number',
#        'Start station', 'End station number', 'End station', 'Bike number',
#        'Member type', 'ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
new = pd.read_csv('/Users/nataliemac/Desktop/VCS/Python/05_Capital_Bike_Share/merged_data.csv')


# Convert datetime column to pandas datetime format
new['datetime'] = pd.to_datetime(new['datetime'], format='%Y-%m-%d %H:%M:%S')
# Out:
# /var/folders/3q/b6hzz54s5l766kwylwkwvjn00000gn/T/ipykernel_31981/3703913263.py:1: DtypeWarning: Columns (1,2,4,6,7,8,9,10,11,12,13,15,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   new = pd.read_csv('/Users/nataliemac/Desktop/VCS/Python/05_Capital_Bike_Share/merged_data.csv')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
new.head(10)
# Out:
#    Duration           Start date             End date  Start station number  \
# 0     506.0  2020-01-01 00:00:59  2020-01-01 00:09:26               31623.0
# 1    1050.0  2020-01-01 00:01:16  2020-01-01 00:18:47               31613.0
# 2    1687.0  2020-01-01 00:02:42  2020-01-01 00:30:50               31218.0
# 3     182.0  2020-01-01 00:02:44  2020-01-01 00:05:47               31627.0
# 4    1002.0  2020-01-01 00:06:12  2020-01-01 00:22:54               31247.0
# 5     980.0  2020-01-01 00:06:32  2020-01-01 00:22:53               31247.0
# 6     974.0  2020-01-01 00:06:49  2020-01-01 00:23:03               31247.0
# 7     424.0  2020-01-01 00:07:52  2020-01-01 00:14:56               31506.0
# 8     683.0  2020-01-01 00:08:10  2020-01-01 00:19:34               31628.0
# 9     676.0  2020-01-01 00:08:20  2020-01-01 00:19:36               31293.0
#
#                                        Start station  End station number  \
# ...

# %%
new.tail()
# Out:
#          Duration Start date End date  Start station number Start station  \
# 2216909       NaN        NaN      NaN                   NaN           NaN
# 2216910       NaN        NaN      NaN                   NaN           NaN
# 2216911       NaN        NaN      NaN                   NaN           NaN
# 2216912       NaN        NaN      NaN                   NaN           NaN
# 2216913       NaN        NaN      NaN                   NaN           NaN
#
#          End station number End station Bike number Member type  \
# 2216909                 NaN         NaN         NaN         NaN
# 2216910                 NaN         NaN         NaN         NaN
# 2216911                 NaN         NaN         NaN         NaN
# 2216912                 NaN         NaN         NaN         NaN
# 2216913                 NaN         NaN         NaN         NaN
#
#                   ride_id  ...             ended_at  \
# 2216909  A10ED3D50E5AB612  ...  2020-12-12 14:17:02
# ...

# %%
# count missing values for red_wine dataset
missing_values_count = new.isnull().sum()

print(missing_values_count)

total_missing = missing_values_count.sum()

print(f'Total missing values: {total_missing}')
# Out:
# Duration                1679514
# Start date              1679514
# End date                1679514
# Start station number    1679514
# Start station           1679514
# End station number      1679514
# End station             1679514
# Bike number             1679514
# Member type             1679514
# ride_id                  537400
# rideable_type            537400
# started_at               537400
# ended_at                 537400
# start_station_name       622039
# start_station_id         622039
# end_station_name         634915
# end_station_id           634915
# start_lat                537408
# start_lng                537408
# end_lat                  543880
# end_lng                  543880
# member_casual            537400
# dtype: int64
# Total missing values: 22479110
